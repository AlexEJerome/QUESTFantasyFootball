# %% [markdown]
# # Standings Test
# First we establish a valid oauth token below:

# %%
from yahoo_oauth import OAuth2
oauth = OAuth2(None, None, from_file='../oauth2.json')
# Out:
# [2019-12-10 22:21:38,911 DEBUG] [yahoo_oauth.yahoo_oauth.__init__] Checking
# [2019-12-10 22:21:38,916 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] ELAPSED TIME : 1454.519255399704
# [2019-12-10 22:21:38,918 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] TOKEN IS STILL VALID

# %% [markdown]
# This will run more frequently - this will check if the token is valid, if not, refresh. Then, we can try to download info from yahoo.

# %%
# %matplotlib inline
from bs4 import BeautifulSoup
import xml.etree.ElementTree as et 
import pandas as pd 

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set_style("white")


if not oauth.token_is_valid():
    oauth.refresh_access_token()
    
df_cols = ["projected points"]
out_df = pd.DataFrame(columns = df_cols)

num_teams = 8

league_ids = [1118202, 1110495, 1112355]

team_name_list = []
dist_series = pd.Series()
series_total = pd.Series()
series_wins = pd.Series()
series_losses = pd.Series()
series_ties = pd.Series()

weeks = 14

for league_num, league_id in enumerate(league_ids):
    for week in range(weeks, weeks+1):
        url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l."+str(league_id)+"/scoreboard;week=" + str(week)
        # url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.1118202/standings"
        # probably migrate to scoreboard when there is data... but unsure
        # url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.854917/scoreboard"
        # https://fantasysports.yahooapis.com/fantasy/v2/team/223.l.431.t.1/matchups;weeks=1,5
        payload = ""
        response = oauth.session.get(url, params=payload)

        # we only want to process data if there's data to pass.
        if not response.status_code == 200:
            print("Status Code Not Valid")
            print(response.text)
        else:

        #   XML Samples which are searchable can be found here: https://developer.yahoo.com/fantasysports/guide/

            soup = BeautifulSoup(response.text, 'lxml')
        #     Remove new line formatting from html to prevent confusion
            clean = str(soup).replace('\n', '')
        #     print(clean)
        #     print(soup.prettify())

        #  Get team Names:
        #     select all name tags beneath team tags
            s_team_names = soup.select('team_projected_points total')
        #     extract the text from the entire tag
            s_team_names = list(map(lambda x: float(x.text), s_team_names))
    #         print(s_team_names)
        #     place that in a fancy little pandas series
            dist_series = dist_series.append(pd.Series(s_team_names), ignore_index=True)
    #         print(dist_series)

            s_total = soup.select('team_points total')
            s_total = list(map(lambda x: float(x.text), s_total))
            series_total = series_total.append(pd.Series(s_total), ignore_index=True)

            tn_l = soup.select('team name')
            tn_l = list(map(lambda x: x.text, tn_l))
            team_name_list+=tn_l
    url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l."+ str(league_id) +"/standings"
    response = oauth.session.get(url)
    if not response.status_code == 200:
        print("Status Code 2nd request Not Valid")
        print(response.text)
    else:
        soup = BeautifulSoup(response.text, 'lxml')
#         print(soup.prettify())
        s_wl_index = soup.select('team name')
        s_wl_index = list(map(lambda x: x.text, s_wl_index))
#         wl_index.append(s_wl_index)

        s_wins = soup.select('wins')
        s_wins = list(map(lambda x: int(x.text), s_wins))
        series_wins = series_wins.append(pd.Series(s_wins, index=s_wl_index))

        s_losses = soup.select('losses')
        s_losses = list(map(lambda x: int(x.text), s_losses))
        series_losses = series_losses.append(pd.Series(s_losses, index=s_wl_index))

        s_ties = soup.select('ties')
        s_ties = list(map(lambda x: int(x.text), s_ties))
        series_ties = series_ties.append(pd.Series(s_ties, index=s_wl_index))

cohorts = pd.read_csv('../cohorts.csv', index_col=0)
leagues = pd.read_csv('../leagues.csv', index_col=0)

data = {"Actual": series_total, "Projected": dist_series, "Team Names": team_name_list}
final_df = pd.DataFrame(data).set_index("Team Names")

final_df['Wins'] = series_wins
final_df['Losses'] = series_losses
final_df['Ties'] = series_ties

df1 = final_df.groupby('Team Names')['Actual'].describe().drop("count", axis=1)
df2 = final_df.groupby('Team Names')['Actual'].sum()

df1["Points For"] = df2

df1['Wins'] = series_wins
df1['Losses'] = series_losses
df1['Ties'] = series_ties
df1['Cohort'] = cohorts
df1['Leagues'] = leagues
df1_cols = df1.columns.tolist()
df1_cols = df1_cols[-5:] + df1_cols[:-5]

df1 = df1[df1_cols]

df1 = df1.sort_values(by=['Wins',"Points For"], ascending=[False,False])
df1 = df1.reset_index()
df1.index +=1


display(df1)
# The order is different int this call (by standing), so index must be assigned in the series then matched up with the final df
df2 = df2.to_frame()
df3 = df2.copy()

df3['Leagues'] = leagues
df4 = df3.copy()
df3 = df3.groupby('Leagues')['Actual'].std().sort_values(ascending=False)
df4 = df4.groupby('Leagues')['Actual'].mean().sort_values(ascending=False)
df5 = df4.copy().to_frame()
df5['League PF Standard Deviation'] = df3
display(df3)
display(df4)
display(df5)


sns.barplot(x=df3.index, y=df3.values).set(ylabel="Std Deviation of Scores")

df_z = df1.copy()
df_z = df_z.join(df5, on="Leagues").rename(columns={"Actual":"League PF Mean"})
df_z['League Z Score'] = (df_z["Points For"]-df_z["League PF Mean"])/df_z['League PF Standard Deviation']
df_z = df_z.sort_values(by=["Wins","League Z Score"], ascending=[False,False])
df_z = df_z.reset_index()
# when you no longer need old rank
# df_z = df_z.reset_index(drop="true")
df_z.index +=1
df_z = df_z.rename(columns={"index":"Old Rank"})
display(df_z)
# Out:
# [2019-12-10 22:21:39,905 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] ELAPSED TIME : 1455.5088021755219
# [2019-12-10 22:21:39,907 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] TOKEN IS STILL VALID
#               Team Names  Wins  Losses  Ties Cohort  Leagues    mean  std  \
# 1                Bow Tie    11       3     0     QG        3  119.88  NaN
# 2             Six Sigmas    11       3     0     25        2  102.92  NaN
# 3         Action Macklin    10       4     0     QG        1  137.50  NaN
# 4    Ball istic Missiles    10       4     0     26        3  122.10  NaN
# 5          Summer's Team    10       4     0     25        2  111.18  NaN
# 6            Mike's Team     9       5     0     33        1  106.80  NaN
# 7    Haskin' For Trouble     8       6     0     23        1  130.84  NaN
# 8   Diehydrogen Monoxyde     8       6     0     29        3  126.80  NaN
# 9            QUESTaceans     8       6     0     23        1  116.48  NaN
# 10         Rachel's Team     8       6     0     QG        1   99.40  NaN
# 11          Bobby's Team     7       7     0     21        3  169.52  NaN
# 12  Discount Doublecheck     7       7     0     30        2  100.20  NaN
# 13        Shannon Larson     7       7     0     25        2   97.20  NaN
# 14  Hot Chubb Time Machi     7       7     0     25        2   87.30  NaN
# 15     The Butt Fumblers     6       8     0     33        2  132.24  NaN
# 16            Drew bLees     6       8     0     23        1  108.96  NaN
# 17             I Eat Mop     6       8     0     30        2   96.48  NaN
# 18       Matthew Masison     6       8     0     27        3   96.36  NaN
# 19         Dustin's Team     6       8     0     24        1   91.18  NaN
# 20      Sherlock Mahomes     5       9     0     21        3  128.32  NaN
# 21    Mayfield of Dreams     5       9     0     32        3   87.56  NaN
# 22          Jason's Team     4      10     0     24        3   89.70  NaN
# 23          MikhailMusic     2      12     0     29        2   74.04  NaN
# 24           McLaurin F1     1      13     0     23        1   89.06  NaN
#
#        min     25%     50%     75%     max  Points For
# 1   119.88  119.88  119.88  119.88  119.88      119.88
# 2   102.92  102.92  102.92  102.92  102.92      102.92
# 3   137.50  137.50  137.50  137.50  137.50      137.50
# 4   122.10  122.10  122.10  122.10  122.10      122.10
# 5   111.18  111.18  111.18  111.18  111.18      111.18
# 6   106.80  106.80  106.80  106.80  106.80      106.80
# 7   130.84  130.84  130.84  130.84  130.84      130.84
# 8   126.80  126.80  126.80  126.80  126.80      126.80
# 9   116.48  116.48  116.48  116.48  116.48      116.48
# 10   99.40   99.40   99.40   99.40   99.40       99.40
# 11  169.52  169.52  169.52  169.52  169.52      169.52
# 12  100.20  100.20  100.20  100.20  100.20      100.20
# 13   97.20   97.20   97.20   97.20   97.20       97.20
# 14   87.30   87.30   87.30   87.30   87.30       87.30
# 15  132.24  132.24  132.24  132.24  132.24      132.24
# 16  108.96  108.96  108.96  108.96  108.96      108.96
# 17   96.48   96.48   96.48   96.48   96.48       96.48
# 18   96.36   96.36   96.36   96.36   96.36       96.36
# 19   91.18   91.18   91.18   91.18   91.18       91.18
# 20  128.32  128.32  128.32  128.32  128.32      128.32
# 21   87.56   87.56   87.56   87.56   87.56       87.56
# 22   89.70   89.70   89.70   89.70   89.70       89.70
# 23   74.04   74.04   74.04   74.04   74.04       74.04
# 24   89.06   89.06   89.06   89.06   89.06       89.06
# Leagues
# 3    26.866344
# 1    17.520998
# 2    17.021475
# Name: Actual, dtype: float64
# Leagues
# 3    117.5300
# 1    110.0275
# 2    100.1950
# Name: Actual, dtype: float64
#            Actual  League PF Standard Deviation
# Leagues
# 3        117.5300                     26.866344
# 1        110.0275                     17.520998
# 2        100.1950                     17.021475
#     Old Rank            Team Names  Wins  Losses  Ties Cohort  Leagues  \
# 1          2            Six Sigmas    11       3     0     25        2
# 2          1               Bow Tie    11       3     0     QG        3
# 3          3        Action Macklin    10       4     0     QG        1
# 4          5         Summer's Team    10       4     0     25        2
# 5          4   Ball istic Missiles    10       4     0     26        3
# 6          6           Mike's Team     9       5     0     33        1
# 7          7   Haskin' For Trouble     8       6     0     23        1
# 8          9           QUESTaceans     8       6     0     23        1
# 9          8  Diehydrogen Monoxyde     8       6     0     29        3
# 10        10         Rachel's Team     8       6     0     QG        1
# 11        11          Bobby's Team     7       7     0     21        3
# 12        12  Discount Doublecheck     7       7     0     30        2
# 13        13        Shannon Larson     7       7     0     25        2
# 14        14  Hot Chubb Time Machi     7       7     0     25        2
# 15        15     The Butt Fumblers     6       8     0     33        2
# 16        16            Drew bLees     6       8     0     23        1
# 17        17             I Eat Mop     6       8     0     30        2
# 18        18       Matthew Masison     6       8     0     27        3
