# %% [markdown]
# # Standings Test
# First we establish a valid oauth token below:

# %%
from yahoo_oauth import OAuth2
oauth = OAuth2(None, None, from_file='../oauth2.json')
# Out:
# [2019-11-26 23:48:48,599 DEBUG] [yahoo_oauth.yahoo_oauth.__init__] Checking
# [2019-11-26 23:48:48,602 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] ELAPSED TIME : 79778.94464325905
# [2019-11-26 23:48:48,603 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] TOKEN HAS EXPIRED
# [2019-11-26 23:48:48,604 DEBUG] [yahoo_oauth.yahoo_oauth.refresh_access_token] REFRESHING TOKEN

# %% [markdown]
# This will run more frequently - this will check if the token is valid, if not, refresh. Then, we can try to download info from yahoo.

# %%
# %matplotlib inline
from bs4 import BeautifulSoup
import xml.etree.ElementTree as et 
import pandas as pd 

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set_style("white")


if not oauth.token_is_valid():
    oauth.refresh_access_token()
    
df_cols = ["projected points"]
out_df = pd.DataFrame(columns = df_cols)

num_teams = 8

league_ids = [1118202, 1110495, 1112355]

team_name_list = []
dist_series = pd.Series()
series_total = pd.Series()
series_wins = pd.Series()
series_losses = pd.Series()
series_ties = pd.Series()

weeks = 12

for league_num, league_id in enumerate(league_ids):
    for week in range(1, weeks+1):
        url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l."+str(league_id)+"/scoreboard;week=" + str(week)
        # url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.1118202/standings"
        # probably migrate to scoreboard when there is data... but unsure
        # url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.854917/scoreboard"
        # https://fantasysports.yahooapis.com/fantasy/v2/team/223.l.431.t.1/matchups;weeks=1,5
        payload = ""
        response = oauth.session.get(url, params=payload)

        # we only want to process data if there's data to pass.
        if not response.status_code == 200:
            print("Status Code Not Valid")
            print(response.text)
        else:

        #   XML Samples which are searchable can be found here: https://developer.yahoo.com/fantasysports/guide/

            soup = BeautifulSoup(response.text, 'lxml')
        #     Remove new line formatting from html to prevent confusion
            clean = str(soup).replace('\n', '')
        #     print(clean)
        #     print(soup.prettify())

        #  Get team Names:
        #     select all name tags beneath team tags
            s_team_names = soup.select('team_projected_points total')
        #     extract the text from the entire tag
            s_team_names = list(map(lambda x: float(x.text), s_team_names))
    #         print(s_team_names)
        #     place that in a fancy little pandas series
            dist_series = dist_series.append(pd.Series(s_team_names), ignore_index=True)
    #         print(dist_series)

            s_total = soup.select('team_points total')
            s_total = list(map(lambda x: float(x.text), s_total))
            series_total = series_total.append(pd.Series(s_total), ignore_index=True)

            tn_l = soup.select('team name')
            tn_l = list(map(lambda x: x.text, tn_l))
            team_name_list+=tn_l
    url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l."+ str(league_id) +"/standings"
    response = oauth.session.get(url)
    if not response.status_code == 200:
        print("Status Code 2nd request Not Valid")
        print(response.text)
    else:
        soup = BeautifulSoup(response.text, 'lxml')
#         print(soup.prettify())
        s_wl_index = soup.select('team name')
        s_wl_index = list(map(lambda x: x.text, s_wl_index))
#         wl_index.append(s_wl_index)

        s_wins = soup.select('wins')
        s_wins = list(map(lambda x: int(x.text), s_wins))
        series_wins = series_wins.append(pd.Series(s_wins, index=s_wl_index))

        s_losses = soup.select('losses')
        s_losses = list(map(lambda x: int(x.text), s_losses))
        series_losses = series_losses.append(pd.Series(s_losses, index=s_wl_index))

        s_ties = soup.select('ties')
        s_ties = list(map(lambda x: int(x.text), s_ties))
        series_ties = series_ties.append(pd.Series(s_ties, index=s_wl_index))

cohorts = pd.read_csv('../cohorts.csv', index_col=0)
leagues = pd.read_csv('../leagues.csv', index_col=0)

data = {"Actual": series_total, "Projected": dist_series, "Team Names": team_name_list}
final_df = pd.DataFrame(data).set_index("Team Names")

final_df['Wins'] = series_wins
final_df['Losses'] = series_losses
final_df['Ties'] = series_ties

df1 = final_df.groupby('Team Names')['Actual'].describe().drop("count", axis=1)
df2 = final_df.groupby('Team Names')['Actual'].sum()

df1["Points For"] = df2

df1['Wins'] = series_wins
df1['Losses'] = series_losses
df1['Ties'] = series_ties
df1['Cohort'] = cohorts
df1['Leagues'] = leagues
df1_cols = df1.columns.tolist()
df1_cols = df1_cols[-5:] + df1_cols[:-5]

df1 = df1[df1_cols]

df1 = df1.sort_values(by=['Wins',"Points For"], ascending=[False,False])
df1 = df1.reset_index()
df1.index +=1


display(df1)
# The order is different int this call (by standing), so index must be assigned in the series then matched up with the final df
df2 = df2.to_frame()
df3 = df2.copy()

df3['Leagues'] = leagues
df4 = df3.copy()
df3 = df3.groupby('Leagues')['Actual'].std().sort_values(ascending=False)
df4 = df4.groupby('Leagues')['Actual'].mean().sort_values(ascending=False)
df5 = df4.copy().to_frame()
df5['League PF Standard Deviation'] = df3
display(df3)
display(df4)
display(df5)


sns.barplot(x=df3.index, y=df3.values).set(ylabel="Std Deviation of Scores")

df_z = df1.copy()
df_z = df_z.join(df5, on="Leagues").rename(columns={"Actual":"League PF Mean"})
df_z['League Z Score'] = (df_z["Points For"]-df_z["League PF Mean"])/df_z['League PF Standard Deviation']
df_z = df_z.sort_values(by=["Wins","League Z Score"], ascending=[False,False])
df_z = df_z.reset_index()
# when you no longer need old rank
# df_z = df_z.reset_index(drop="true")
df_z.index +=1
df_z = df_z.rename(columns={"index":"Old Rank"})
display(df_z)
# Out:
# [2019-11-26 23:48:50,121 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] ELAPSED TIME : 1.5156233310699463
# [2019-11-26 23:48:50,124 DEBUG] [yahoo_oauth.yahoo_oauth.token_is_valid] TOKEN IS STILL VALID
#               Team Names  Wins  Losses  Ties Cohort  Leagues        mean  \
# 1            Mike's Team     9       3     0     33        1  128.661667
# 2             Six Sigmas     9       3     0     25        2  127.728333
# 3         Action Macklin     9       3     0     QG        1  126.106667
# 4                Bow Tie     9       3     0     QG        3  117.161667
# 5    Ball istic Missiles     8       4     0     26        3  128.383333
# 6          Summer's Team     8       4     0     25        2  119.326667
# 7          Rachel's Team     7       5     0     QG        1  126.946667
# 8   Diehydrogen Monoxyde     7       5     0     29        3  121.895000
# 9    Haskin' For Trouble     7       5     0     23        1  114.520000
# 10          Bobby's Team     6       6     0     21        3  119.868333
# 11           QUESTaceans     6       6     0     23        1  118.366667
# 12        Shannon Larson     6       6     0     25        2  115.698333
# 13  Hot Chubb Time Machi     6       6     0     25        2  113.593333
# 14       Matthew Masison     6       6     0     27        3  105.948333
# 15  Discount Doublecheck     6       6     0     30        2  105.733333
# 16             I Eat Mop     6       6     0     30        2  104.413333
# 17            Drew bLees     5       7     0     23        1  114.731667
# 18    Mayfield of Dreams     5       7     0     32        3  106.963333
# 19     The Butt Fumblers     5       7     0     33        2  105.935000
# 20      Sherlock Mahomes     4       8     0     21        3  105.601667
# 21         Dustin's Team     4       8     0     24        1  101.148333
# 22          Jason's Team     3       9     0     24        3   92.025000
# 23          MikhailMusic     2      10     0     29        2  110.876667
# 24           McLaurin F1     1      11     0     23        1   85.641667
#
#           std    min      25%     50%      75%     max  Points For
# 1   18.300278  89.42  118.290  127.51  145.450  153.40     1543.94
# 2   28.985382  93.88  109.910  115.51  135.905  193.54     1532.74
# 3   25.176428  88.70  111.985  121.98  141.090  164.32     1513.28
# 4   27.018684  68.56  103.695  114.31  135.735  166.88     1405.94
# 5   30.052496  90.92   96.480  134.34  155.530  172.26     1540.60
# 6   21.558901  68.26  111.780  121.56  130.725  147.46     1431.92
# 7   18.578714  95.94  115.535  127.54  145.125  147.70     1523.36
# 8   22.464265  79.90  107.900  128.59  134.735  158.42     1462.74
# 9   23.043706  89.10   95.250  111.61  123.000  161.12     1374.24
# 10  26.220772  81.46  101.595  112.72  139.945  165.80     1438.42
# 11  24.604721  82.96   98.345  113.17  140.720  156.70     1420.40
# 12  23.766151  84.40   99.020  113.29  122.105  171.30     1388.38
# 13  22.964177  87.22   99.450  105.05  129.150  163.46     1363.12
# 14  31.089702  71.48   84.455   96.15  123.770  173.42     1271.38
# 15  20.452623  72.78   89.230  106.92  121.785  135.66     1268.80
# 16  32.521806  56.76   75.140  106.97  132.780  150.52     1252.96
# 17  28.291315  81.96   93.300  112.03  131.470  169.44     1376.78
# 18  18.923188  83.10   90.555  106.19  121.160  138.42     1283.56
# 19  15.602585  80.72   95.415  101.04  117.815  128.32     1271.22
# 20  18.817322  76.40   91.620  106.56  123.185  133.36     1267.22
# 21  33.650089  44.36   87.050  101.77  111.965  176.96     1213.78
# 22  29.699954  35.60   76.395   90.12  116.530  135.74     1104.30
# 23  32.102212  66.70   92.800  110.31  122.935  190.62     1330.52
# 24  24.933808  31.10   73.370   85.07   99.155  126.86     1027.70
# Leagues
# 1    176.611576
# 3    140.264536
# 2     95.729753
# Name: Actual, dtype: float64
# Leagues
# 1    1374.1850
# 2    1354.9575
# 3    1346.7700
# Name: Actual, dtype: float64
#             Actual  League PF Standard Deviation
# Leagues
# 1        1374.1850                    176.611576
# 2        1354.9575                     95.729753
# 3        1346.7700                    140.264536
#     Old Rank            Team Names  Wins  Losses  Ties Cohort  Leagues  \
# 1          2            Six Sigmas     9       3     0     25        2
# 2          1           Mike's Team     9       3     0     33        1
# 3          3        Action Macklin     9       3     0     QG        1
# 4          4               Bow Tie     9       3     0     QG        3
# 5          5   Ball istic Missiles     8       4     0     26        3
# 6          6         Summer's Team     8       4     0     25        2
# 7          7         Rachel's Team     7       5     0     QG        1
# 8          8  Diehydrogen Monoxyde     7       5     0     29        3
# 9          9   Haskin' For Trouble     7       5     0     23        1
# 10        10          Bobby's Team     6       6     0     21        3
# 11        12        Shannon Larson     6       6     0     25        2
# 12        11           QUESTaceans     6       6     0     23        1
# 13        13  Hot Chubb Time Machi     6       6     0     25        2
# 14        14       Matthew Masison     6       6     0     27        3
# 15        15  Discount Doublecheck     6       6     0     30        2
# 16        16             I Eat Mop     6       6     0     30        2
# 17        17            Drew bLees     5       7     0     23        1
# 18        18    Mayfield of Dreams     5       7     0     32        3
# 19        19     The Butt Fumblers     5       7     0     33        2
# 20        20      Sherlock Mahomes     4       8     0     21        3
# 21        21         Dustin's Team     4       8     0     24        1
# 22        22          Jason's Team     3       9     0     24        3
# 23        23          MikhailMusic     2      10     0     29        2
# 24        24           McLaurin F1     1      11     0     23        1
#
#           mean        std    min      25%     50%      75%     max  \
# 1   127.728333  28.985382  93.88  109.910  115.51  135.905  193.54
# 2   128.661667  18.300278  89.42  118.290  127.51  145.450  153.40
# 3   126.106667  25.176428  88.70  111.985  121.98  141.090  164.32
# 4   117.161667  27.018684  68.56  103.695  114.31  135.735  166.88
# 5   128.383333  30.052496  90.92   96.480  134.34  155.530  172.26
# 6   119.326667  21.558901  68.26  111.780  121.56  130.725  147.46
# 7   126.946667  18.578714  95.94  115.535  127.54  145.125  147.70
# 8   121.895000  22.464265  79.90  107.900  128.59  134.735  158.42
# 9   114.520000  23.043706  89.10   95.250  111.61  123.000  161.12
# 10  119.868333  26.220772  81.46  101.595  112.72  139.945  165.80
# 11  115.698333  23.766151  84.40   99.020  113.29  122.105  171.30
# 12  118.366667  24.604721  82.96   98.345  113.17  140.720  156.70
# 13  113.593333  22.964177  87.22   99.450  105.05  129.150  163.46
# 14  105.948333  31.089702  71.48   84.455   96.15  123.770  173.42
# 15  105.733333  20.452623  72.78   89.230  106.92  121.785  135.66
# 16  104.413333  32.521806  56.76   75.140  106.97  132.780  150.52
# 17  114.731667  28.291315  81.96   93.300  112.03  131.470  169.44
# 18  106.963333  18.923188  83.10   90.555  106.19  121.160  138.42
# 19  105.935000  15.602585  80.72   95.415  101.04  117.815  128.32
# 20  105.601667  18.817322  76.40   91.620  106.56  123.185  133.36
# 21  101.148333  33.650089  44.36   87.050  101.77  111.965  176.96
# 22   92.025000  29.699954  35.60   76.395   90.12  116.530  135.74
# 23  110.876667  32.102212  66.70   92.800  110.31  122.935  190.62
# 24   85.641667  24.933808  31.10   73.370   85.07   99.155  126.86
#
#     Points For  League PF Mean  League PF Standard Deviation  League Z Score
# 1      1532.74       1354.9575                     95.729753        1.857129
# 2      1543.94       1374.1850                    176.611576        0.961177
# 3      1513.28       1374.1850                    176.611576        0.787576
# 4      1405.94       1346.7700                    140.264536        0.421846
# 5      1540.60       1346.7700                    140.264536        1.381889
# 6      1431.92       1354.9575                     95.729753        0.803956
# 7      1523.36       1374.1850                    176.611576        0.844650
# 8      1462.74       1346.7700                    140.264536        0.826795
# 9      1374.24       1374.1850                    176.611576        0.000311
# 10     1438.42       1346.7700                    140.264536        0.653408
# 11     1388.38       1354.9575                     95.729753        0.349134
# 12     1420.40       1374.1850                    176.611576        0.261676
# 13     1363.12       1354.9575                     95.729753        0.085266
# 14     1271.38       1346.7700                    140.264536       -0.537484
# 15     1268.80       1354.9575                     95.729753       -0.900008
# 16     1252.96       1354.9575                     95.729753       -1.065473
# 17     1376.78       1374.1850                    176.611576        0.014693
# 18     1283.56       1346.7700                    140.264536       -0.450648
# 19     1271.22       1354.9575                     95.729753       -0.874728
# 20     1267.22       1346.7700                    140.264536       -0.567143
# 21     1213.78       1374.1850                    176.611576       -0.908236
# 22     1104.30       1346.7700                    140.264536       -1.728662
# 23     1330.52       1354.9575                     95.729753       -0.255276
# 24     1027.70       1374.1850                    176.611576       -1.961848
