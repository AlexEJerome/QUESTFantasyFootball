# %% [markdown]
# # Standings Test
# First we establish a valid oauth token below:

# %%
from yahoo_oauth import OAuth2
oauth = OAuth2(None, None, from_file='../oauth2.json')
# Out:
# [2022-09-22 21:38:41,822 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2022-09-22 21:38:41,830 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 117.01446628570557
# [2022-09-22 21:38:41,833 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID

# %% [markdown]
# This will run more frequently - this will check if the token is valid, if not, refresh. Then, we can try to download info from yahoo.

# %%
### %matplotlib inline
from bs4 import BeautifulSoup
import lxml
import xml.etree.ElementTree as et 
import pandas as pd 

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set_style("white")


if not oauth.token_is_valid():
    oauth.refresh_access_token()
    
df_cols = ["projected points"]
out_df = pd.DataFrame(columns = df_cols)

num_teams = 10

league_ids = {1120920: "Alex", 660108: "Mike", 1024668: "Jack"}

team_name_list = []
dist_series = pd.Series()
series_total = pd.Series()
series_wins = pd.Series()
series_losses = pd.Series()
series_ties = pd.Series()
series_leagues = pd.Series()

weeks = 2

for league_id, league_name in league_ids.items():
    for week in range(1, weeks+1):
        url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l."+str(league_id)+"/scoreboard;week=" + str(week)
        # url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.1118202/standings"
        # probably migrate to scoreboard when there is data... but unsure
        # url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.854917/scoreboard"
        # https://fantasysports.yahooapis.com/fantasy/v2/team/223.l.431.t.1/matchups;weeks=1,5
        payload = ""
        response = oauth.session.get(url, params=payload)

        # we only want to process data if there's data to pass.
        if not response.status_code == 200:
            print("Status Code Not Valid")
            print(response.text)
        else:

        #   XML Samples which are searchable can be found here: https://developer.yahoo.com/fantasysports/guide/

            soup = BeautifulSoup(response.text, 'lxml')
        #     Remove new line formatting from html to prevent confusion
            clean = str(soup).replace('\n', '')
        #     print(clean)
        #     print(soup.prettify())

        #  Get team Names:
        #     select all name tags beneath team tags
            s_team_names = soup.select('team_projected_points total')
        #     extract the text from the entire tag
            s_team_names = list(map(lambda x: float(x.text), s_team_names))
    #         print(s_team_names)
        #     place that in a fancy little pandas series
            dist_series = dist_series.append(pd.Series(s_team_names), ignore_index=True)
    #         print(dist_series)

            s_total = soup.select('team_points total')
            s_total = list(map(lambda x: float(x.text), s_total))
            series_total = series_total.append(pd.Series(s_total), ignore_index=True)

            tn_l = soup.select('team name')
            tn_l = list(map(lambda x: x.text, tn_l))
            team_name_list+=tn_l
    url = "https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l."+ str(league_id) +"/standings"
    response = oauth.session.get(url)
    if not response.status_code == 200:
        print("Status Code 2nd request Not Valid")
        print(response.text)
    else:
        soup = BeautifulSoup(response.text, 'lxml')
#         print(soup.prettify())
        s_wl_index = soup.select('team name')
        s_wl_index = list(map(lambda x: x.text, s_wl_index))
#         wl_index.append(s_wl_index)

        s_wins = soup.select('wins')
        s_wins = list(map(lambda x: int(x.text), s_wins))
        series_wins = series_wins.append(pd.Series(s_wins, index=s_wl_index))

        s_losses = soup.select('losses')
        s_losses = list(map(lambda x: int(x.text), s_losses))
        series_losses = series_losses.append(pd.Series(s_losses, index=s_wl_index))

        s_ties = soup.select('ties')
        s_ties = list(map(lambda x: int(x.text), s_ties))
        series_ties = series_ties.append(pd.Series(s_ties, index=s_wl_index))
        
#         Add the league names
        s_leagues = [league_name] * num_teams
        series_leagues = series_leagues.append(pd.Series(s_leagues, index= s_wl_index))

cohorts = pd.read_csv('../cohorts.csv', index_col=0)
# leagues = pd.read_csv('../leagues.csv', index_col=0)

data = {"Actual": series_total, "Projected": dist_series, "Team Names": team_name_list}
final_df = pd.DataFrame(data).set_index("Team Names")

final_df['Wins'] = series_wins
final_df['Losses'] = series_losses
final_df['Ties'] = series_ties
final_df['League'] = series_leagues

df1 = final_df.groupby('Team Names')['Actual'].describe().drop("count", axis=1)
df2 = final_df.groupby('Team Names')['Actual'].sum()

df1["Points For"] = df2

df1['Wins'] = series_wins
df1['Losses'] = series_losses
df1['Ties'] = series_ties
# df1['Cohort'] = cohorts
# df1['Leagues'] = leagues
df1['Leagues'] = series_leagues
df1_cols = df1.columns.tolist()
df1_cols = df1_cols[-5:] + df1_cols[:-5]

df1 = df1[df1_cols]

df1 = df1.sort_values(by=['Wins',"Points For"], ascending=[False,False])
df1 = df1.reset_index()
df1.index +=1


display(df1)
# The order is different int this call (by standing), so index must be assigned in the series then matched up with the final df
df2 = df2.to_frame()
df3 = df2.copy()

# df3['Leagues'] = leagues
df3['Leagues'] = series_leagues
df4 = df3.copy()
df3 = df3.groupby('Leagues')['Actual'].std().sort_values(ascending=False)
df4 = df4.groupby('Leagues')['Actual'].mean().sort_values(ascending=False)
df5 = df4.copy().to_frame()
df5['League PF Standard Deviation'] = df3
display(df3)
display(df4)
display(df5)


sns.barplot(x=df3.index, y=df3.values).set(ylabel="Std Deviation of Scores")

df_z = df1.copy()
df_z = df_z.join(df5, on="Leagues").rename(columns={"Actual":"League PF Mean"})
df_z['League Z Score'] = (df_z["Points For"]-df_z["League PF Mean"])/df_z['League PF Standard Deviation']
df_z = df_z.sort_values(by=["Wins","League Z Score"], ascending=[False,False])
df_z = df_z.reset_index()
# when you no longer need old rank
# df_z = df_z.reset_index(drop="true")
df_z.index +=1
df_z = df_z.rename(columns={"index":"PF Rank"})
display(df_z)
# Out:
# [2022-09-22 21:40:57,222 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 252.4064347743988
# [2022-09-22 21:40:57,223 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# <ipython-input-9-e86705d2532b>:26: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dist_series = pd.Series()
# <ipython-input-9-e86705d2532b>:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series_total = pd.Series()
# <ipython-input-9-e86705d2532b>:28: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series_wins = pd.Series()
# <ipython-input-9-e86705d2532b>:29: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series_losses = pd.Series()
# <ipython-input-9-e86705d2532b>:30: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series_ties = pd.Series()
# <ipython-input-9-e86705d2532b>:31: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series_leagues = pd.Series()
#                      Team Names  Points For  Wins  Losses  Ties Leagues  \
# 1                  Guild Ed Age      267.94     2       0     0    Jack
# 2   Mike White is not Elite Nvm      264.56     2       0     0    Jack
# 3               CheeseHeadChoke      264.30     2       0     0    Alex
# 4                   QUESTy Qrab      257.80     2       0     0    Mike
# 5      Dan Snyder’s Evil Empire      256.80     2       0     0    Jack
# 6        The Spaghetti Diagrams      232.14     2       0     0    Alex
# 7              Zeke and Destroy      204.12     2       0     0    Mike
# 8   alexanderhill96's Swag Team      268.14     1       1     0    Alex
# 9                 Summer's Team      264.06     1       1     0    Mike
# 10          Dustin's Dandy Team      259.98     1       1     0    Mike
# 11       Ansh's Astounding Team      259.30     1       1     0    Jack
# 12                Andrew's Team      256.14     1       1     0    Mike
# 13     Pavan's QUEST for a Ring      246.84     1       1     0    Alex
# 14      Jess's Lamarvelous Team      228.24     1       1     0    Mike
# 15       Pranav's Peerless Team      224.68     1       1     0    Alex
# 16         Ayman's Amazing Team      224.56     1       1     0    Alex
# 17            The Better Bailey      224.42     1       1     0    Alex
# 18                    Flip Kupp      221.98     1       1     0    Jack
# 19              Obi-Won Mahomie      216.90     1       1     0    Alex
# 20               Cardiac Aquest      213.20     1       1     0    Mike
# 21              Barkley's Knees      203.22     1       1     0    Jack
# 22      Sareet's Slam-Dunk Team      197.36     1       1     0    Jack
# 23                  Taylor-Made      196.86     1       1     0    Mike
# 24             The Ethan Allens      222.96     0       2     0    Alex
# 25    lets see paul allen’s wr3      206.96     0       2     0    Jack
# 26         Fishbone Diagrammies      205.54     0       2     0    Jack
# 27            Jean's Swell Team      204.18     0       2     0    Jack
# 28     Najee see me Najee don’t      199.48     0       2     0    Mike
# 29                 Eitan's Team      185.64     0       2     0    Mike
# 30    Patrick's Phenomenal Team      143.08     0       2     0    Alex
#
#       mean        std     min      25%     50%      75%     max
# 1   133.97   4.313351  130.92  132.445  133.97  135.495  137.02
# 2   132.28  27.860007  112.58  122.430  132.28  142.130  151.98
# 3   132.15  42.610255  102.02  117.085  132.15  147.215  162.28
# 4   128.90  12.869343  119.80  124.350  128.90  133.450  138.00
# 5   128.40   8.032733  122.72  125.560  128.40  131.240  134.08
# 6   116.07   2.050610  114.62  115.345  116.07  116.795  117.52
# 7   102.06  21.354625   86.96   94.510  102.06  109.610  117.16
# 8   134.07   1.909188  132.72  133.395  134.07  134.745  135.42
# 9   132.03  20.435386  117.58  124.805  132.03  139.255  146.48
# 10  129.99  38.707025  102.62  116.305  129.99  143.675  157.36
# 11  129.65  10.111627  122.50  126.075  129.65  133.225  136.80
# 12  128.07  11.101576  120.22  124.145  128.07  131.995  135.92
# 13  123.42  51.562226   86.96  105.190  123.42  141.650  159.88
# 14  114.12  51.901638   77.42   95.770  114.12  132.470  150.82
# 15  112.34   7.523616  107.02  109.680  112.34  115.000  117.66
# 16  112.28   9.927779  105.26  108.770  112.28  115.790  119.30
# 17  112.21  31.607673   89.86  101.035  112.21  123.385  134.56
# 18  110.99   4.115361  108.08  109.535  110.99  112.445  113.90
# 19  108.45  41.507168   79.10   93.775  108.45  123.125  137.80
# 20  106.60   9.729789   99.72  103.160  106.60  110.040  113.48
# 21  101.61  14.212846   91.56   96.585  101.61  106.635  111.66
# 22   98.68  26.898342   79.66   89.170   98.68  108.190  117.70
# 23   98.43  21.170777   83.46   90.945   98.43  105.915  113.40
# 24  111.48   7.071068  106.48  108.980  111.48  113.980  116.48
# 25  103.48   7.947880   97.86  100.670  103.48  106.290  109.10
# 26  102.77  23.405234   86.22   94.495  102.77  111.045  119.32
# 27  102.09  17.635243   89.62   95.855  102.09  108.325  114.56
# 28   99.74  18.469629   86.68   93.210   99.74  106.270  112.80
# 29   92.82   7.580185   87.46   90.140   92.82   95.500   98.18
# 30   71.54   8.117586   65.80   68.670   71.54   74.410   77.28
# Leagues
# Alex    34.451791
# Mike    30.457234
# Jack    29.511664
# Name: Actual, dtype: float64
# Leagues
# Jack    228.784
# Alex    226.802
# Mike    226.552
# Name: Actual, dtype: float64
#           Actual  League PF Standard Deviation
# Leagues
# Jack     228.784                     29.511664
# Alex     226.802                     34.451791
# Mike     226.552                     30.457234
#     PF Rank                   Team Names  Points For  Wins  Losses  Ties  \
# 1         1                 Guild Ed Age      267.94     2       0     0
# 2         2  Mike White is not Elite Nvm      264.56     2       0     0
# 3         3              CheeseHeadChoke      264.30     2       0     0
# 4         4                  QUESTy Qrab      257.80     2       0     0
# 5         5     Dan Snyder’s Evil Empire      256.80     2       0     0
# 6         6       The Spaghetti Diagrams      232.14     2       0     0
# 7         7             Zeke and Destroy      204.12     2       0     0
# 8         9                Summer's Team      264.06     1       1     0
# 9         8  alexanderhill96's Swag Team      268.14     1       1     0
# 10       10          Dustin's Dandy Team      259.98     1       1     0
# 11       11       Ansh's Astounding Team      259.30     1       1     0
# 12       12                Andrew's Team      256.14     1       1     0
# 13       13     Pavan's QUEST for a Ring      246.84     1       1     0
# 14       14      Jess's Lamarvelous Team      228.24     1       1     0
# 15       15       Pranav's Peerless Team      224.68     1       1     0
# 16       16         Ayman's Amazing Team      224.56     1       1     0
# 17       17            The Better Bailey      224.42     1       1     0
# 18       18                    Flip Kupp      221.98     1       1     0
# 19       19              Obi-Won Mahomie      216.90     1       1     0
# 20       20               Cardiac Aquest      213.20     1       1     0
# 21       21              Barkley's Knees      203.22     1       1     0
# 22       23                  Taylor-Made      196.86     1       1     0
# 23       22      Sareet's Slam-Dunk Team      197.36     1       1     0
# 24       24             The Ethan Allens      222.96     0       2     0
# 25       25    lets see paul allen’s wr3      206.96     0       2     0
# 26       26         Fishbone Diagrammies      205.54     0       2     0
# 27       27            Jean's Swell Team      204.18     0       2     0
# 28       28     Najee see me Najee don’t      199.48     0       2     0
# 29       29                 Eitan's Team      185.64     0       2     0
# 30       30    Patrick's Phenomenal Team      143.08     0       2     0
#
#    Leagues    mean        std     min      25%     50%      75%     max  \
# 1     Jack  133.97   4.313351  130.92  132.445  133.97  135.495  137.02
# 2     Jack  132.28  27.860007  112.58  122.430  132.28  142.130  151.98
# 3     Alex  132.15  42.610255  102.02  117.085  132.15  147.215  162.28
# 4     Mike  128.90  12.869343  119.80  124.350  128.90  133.450  138.00
# 5     Jack  128.40   8.032733  122.72  125.560  128.40  131.240  134.08
# 6     Alex  116.07   2.050610  114.62  115.345  116.07  116.795  117.52
# 7     Mike  102.06  21.354625   86.96   94.510  102.06  109.610  117.16
# 8     Mike  132.03  20.435386  117.58  124.805  132.03  139.255  146.48
# 9     Alex  134.07   1.909188  132.72  133.395  134.07  134.745  135.42
# 10    Mike  129.99  38.707025  102.62  116.305  129.99  143.675  157.36
# 11    Jack  129.65  10.111627  122.50  126.075  129.65  133.225  136.80
# 12    Mike  128.07  11.101576  120.22  124.145  128.07  131.995  135.92
# 13    Alex  123.42  51.562226   86.96  105.190  123.42  141.650  159.88
# 14    Mike  114.12  51.901638   77.42   95.770  114.12  132.470  150.82
# 15    Alex  112.34   7.523616  107.02  109.680  112.34  115.000  117.66
# 16    Alex  112.28   9.927779  105.26  108.770  112.28  115.790  119.30
# 17    Alex  112.21  31.607673   89.86  101.035  112.21  123.385  134.56
# 18    Jack  110.99   4.115361  108.08  109.535  110.99  112.445  113.90
# 19    Alex  108.45  41.507168   79.10   93.775  108.45  123.125  137.80
# 20    Mike  106.60   9.729789   99.72  103.160  106.60  110.040  113.48
# 21    Jack  101.61  14.212846   91.56   96.585  101.61  106.635  111.66
# 22    Mike   98.43  21.170777   83.46   90.945   98.43  105.915  113.40
# 23    Jack   98.68  26.898342   79.66   89.170   98.68  108.190  117.70
# 24    Alex  111.48   7.071068  106.48  108.980  111.48  113.980  116.48
# 25    Jack  103.48   7.947880   97.86  100.670  103.48  106.290  109.10
# 26    Jack  102.77  23.405234   86.22   94.495  102.77  111.045  119.32
# 27    Jack  102.09  17.635243   89.62   95.855  102.09  108.325  114.56
# 28    Mike   99.74  18.469629   86.68   93.210   99.74  106.270  112.80
# 29    Mike   92.82   7.580185   87.46   90.140   92.82   95.500   98.18
# 30    Alex   71.54   8.117586   65.80   68.670   71.54   74.410   77.28
#
#     League PF Mean  League PF Standard Deviation  League Z Score
# 1          228.784                     29.511664        1.326797
# 2          228.784                     29.511664        1.212266
# 3          226.802                     34.451791        1.088419
# 4          226.552                     30.457234        1.025963
# 5          228.784                     29.511664        0.949320
# 6          226.802                     34.451791        0.154941
# 7          226.552                     30.457234       -0.736508
# 8          226.552                     30.457234        1.231497
# 9          226.802                     34.451791        1.199880
# 10         226.552                     30.457234        1.097539
# 11         228.784                     29.511664        1.034032
# 12         226.552                     30.457234        0.971460
# 13         226.802                     34.451791        0.581624
# 14         226.552                     30.457234        0.055422
# 15         226.802                     34.451791       -0.061593
# 16         226.802                     34.451791       -0.065076
# 17         226.802                     34.451791       -0.069140
# 18         228.784                     29.511664       -0.230553
# 19         226.802                     34.451791       -0.287416
# 20         226.552                     30.457234       -0.438385
# 21         228.784                     29.511664       -0.866234
# 22         226.552                     30.457234       -0.974875
# 23         228.784                     29.511664       -1.064799
# 24         226.802                     34.451791       -0.111518
# 25         228.784                     29.511664       -0.739504
# 26         228.784                     29.511664       -0.787621
# 27         228.784                     29.511664       -0.833704
# 28         226.552                     30.457234       -0.888853
# 29         226.552                     30.457234       -1.343261
# 30         226.802                     34.451791       -2.430120
